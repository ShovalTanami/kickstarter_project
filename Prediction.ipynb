# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # Part 5 : Prediction
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Import libarary
#
# <br>
# <br>
# <br>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from GlobalFunction import *
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor

pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('float_format', '{:f}'.format)

sns.set(style="white", color_codes=True)

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Read The Data
#
# <br>
# <br>
# <br>

# %%
df = readCSV("fullData.csv")
df.head()
# Out:
#            ID                                               name        category main_category             deadline             launched       state  backers country      pledged         goal  state_value  hour  day  month  year  weekday  duration  backers_median_category  backers_mean_category  success_percent_category  pledged_median_category  goal_median_category                                     tokenized_name                               clean_tokenized_name  name_count_words  \
# 0  1000002330                    The Songs of Adelaide & Abullah          Poetry    Publishing  2015-10-09 00:00:00  2015-08-11 12:12:28      failed        0      GB     0.000000  1533.950000            0    12   11      8  2015        1        59                 0.036496               0.028319                  0.405193                 0.013337              0.045598  ['The', 'Songs', 'of', 'Adelaide', '&', 'Abull...  ['the', 'songs', 'of', 'adelaide', '&', 'abull...                 6
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film  Film & Video  2017-11-01 00:00:00  2017-09-02 04:43:57      failed       15      US  2421.000000 30000.000000            0     4    2      9  2017        5        60                 0.167883               0.176530                  0.455267                 0.133340              0.318284  ['Greeting', 'From', 'Earth', ':', 'ZGAC', 'Ar...  ['greeting', 'from', 'earth', ':', 'zgac', 'ar...                 9
# 2  1000004038                                     Where is Hank?  Narrative Film  Film & Video  2013-02-26 00:00:00  2013-01-12 00:20:50      failed        3      US   220.000000 45000.000000            0     0   12      1  2013        5        45                 0.167883               0.176530                  0.455267                 0.133340              0.318284                       ['Where', 'is', 'Hank', '?']                       ['where', 'is', 'hank', '?']                 4
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music         Music  2012-04-16 00:00:00  2012-03-17 03:24:11      failed        1      US     1.000000  5000.000000            0     3   17      3  2012        5        30                 0.138686               0.096836                  0.573300                 0.065204              0.147856  ['ToshiCapital', 'Rekordz', 'Needs', 'Help', '...  ['toshicapital', 'rekordz', 'needs', 'help', '...                 7
# 4  1000014025                               Monarch Espresso Bar     Restaurants          Food  2016-04-01 00:00:00  2016-02-26 13:38:27  successful      224      US 52375.000000 50000.000000            1    13   26      2  2016        4        35                 0.007299               0.048399                  0.116545                 0.004295              0.829571                     ['Monarch', 'Espresso', 'Bar']                     ['monarch', 'espresso', 'bar']                 3
#
#    clean_name_count_words  words_len_mean  name_number_count  name_time_count  name_url_count  stopword_count  symbol_count  name_len  name_is_question  name_is_exclamation  name_repeating_words  name_is_upper  name_negative_count  name_positive_count  name_buzzwords_count  name_freq_value  name_success_value
# 0                       6        4.333333                  0                0               0               2             1        31                 0                    0                     1       0.000000                    0                    0                     0         0.261817            0.395431
# 1                       9        4.222222                  0                0               0               2             1        45                 0                    0                     1       0.000000                    0                    0                     0         0.040789            0.377525
# 2                       4        3.000000                  1                0               0               2             1        14                 1                    0                     1       0.000000                    0                    0                     0         0.054780            0.428571
# 3                       7        6.142857                  0                0               0               1             0        49                 0                    0                     1       0.000000                    0                    0                     1         0.080881            0.495710
# 4                       3        6.000000                  0                0               0               0             0        20                 0                    0                     1       0.000000                    0                    0                     0         0.001205            0.420636

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # Part 5 : Build Model
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
#
# ## create helper function
#
# <br>

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

def getX(df):
    X = df.copy().select_dtypes(include=numerics)
    X = X.drop(columns=['ID','state_value','pledged','year','backers'])
    return X

def getY(df):
    y = df.copy().state_value.values
    return y

# %% [markdown]
# <br>
#
# ## read test and train data
#
# <br>

# %%
testData = readCSV('TestData.csv')
trainData = readCSV('TrainData.csv')

# %% [markdown]
# <br>
#
# ##  build  Random Forest Classifier model on train data
#
# <br>

# %%
X = getX(trainData)
y = getY(trainData)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rand_forest = RandomForestClassifier(min_samples_split = 2,min_samples_leaf = 5)
rand_forest.fit(X_train,y_train)

y_pred_test = rand_forest.predict(X_test)
test_score = metrics.accuracy_score(y_test, y_pred_test)
print('test score: ' ,test_score)

cv_scores = cross_val_score(rand_forest, X, y, cv=5, scoring='accuracy')
print('cv_mean: ' ,cv_scores.mean())
# Out:
# C:\Users\shova\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# test score:  0.7172230049240469
# cv_mean:  0.717493654936536

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## Evaluate Random Forest Classifier
#
# <br>
# <br>
# <br>

# %%
X_train = getX(trainData)
y_train = getY(trainData)

# %%
rand_forest = RandomForestClassifier(min_samples_split = 2,min_samples_leaf = 5)
rand_forest = rand_forest.fit(X_train,y_train)
# Out:
# C:\Users\shova\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
X_test = getX(testData)
y_test = getY(testData)

# %%
y_pred = rand_forest.predict(X_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.6977165600629914

# %%
feat_importances = pd.Series(rand_forest.feature_importances_, index=X.columns)
feat_importances.sort_values(ascending=True).plot(kind='barh',figsize=(12,8))
plt.show()

# %% [markdown]
# <br>
# <br>
# <br>
#
# #  build decision trees model
#
# <br>
# <br>
# <br>

# %%
X = getX(trainData)
y = getY(trainData)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
parameters_range = [2,3,4,5,7,9,13,17]
parameters = []
test_score_list_dt = []
cv_mean_scores = []

for d in parameters_range:
    for m in parameters_range:
        parameters.append((d,m))
        clf = DecisionTreeClassifier(max_depth=d,min_samples_split=m)
        clf.fit(X_train,y_train)
        
        y_pred_test = clf.predict(X_test)
        test_score = metrics.accuracy_score(y_test, y_pred_test)
        test_score_list_dt.append(test_score)   

        cv_scores = cross_val_score(clf, X, y, cv=5, scoring='accuracy')
        cv_mean_scores.append(cv_scores.mean())

# %%
plt.plot(test_score_list_dt, parameters)
plt.ylabel('Value of parameters for DecisionTree')
plt.xlabel('Testing Accuracy')
# Out:
# Text(0.5, 0, 'Testing Accuracy')

# %%
index = cv_mean_scores.index(max(cv_mean_scores))
maxCV = max(cv_mean_scores)
maxDepth = parameters[index][0]
minSplit = parameters[index][1]
accuracyScore = test_score_list_dt[index]
print('Max of parameters cross validation: ', maxCV)
print("Max depth: " , maxDepth)
print("Min samples split: " , minSplit)
print("Accuracy score on test data: " ,accuracyScore)
# Out:
# Max of parameters cross validation:  0.7163595620973195
# Max depth:  9
# Min samples split:  2
# Accuracy score on test data:  0.7164229071202896

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## Evaluate decision trees
#
# <br>
# <br>
# <br>

# %%
X_train = getX(trainData)
y_train = getY(trainData)

# %%
clf = DecisionTreeClassifier(max_depth=maxDepth,min_samples_split=minSplit)
clf = clf.fit(X,y)

# %%
X_test = getX(testData)
y_test = getY(testData)

# %%
y_pred = clf.predict(X_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.6900259947579036

# %%
feat_importances = pd.Series(clf.feature_importances_, index=X.columns)
feat_importances.sort_values(ascending=True).plot(kind='barh',figsize=(12,8))
plt.show()

# %% [markdown]
# <br>
# <br>
# <br>
#
# #  build KNN model
#
# <br>
# <br>
# <br>

# %%
X = getX(trainData)
y = getY(trainData)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=4)

# %%
k_range = [3,11,17,23,45,57,63,75,91]
knn_scores = []
knn_cv_mean_scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    knn_scores.append(metrics.accuracy_score(y_test, y_pred))
    
    cv_scores = cross_val_score(knn, X, y, cv=5, scoring='accuracy')
    knn_cv_mean_scores.append(cv_scores.mean())

# %%
plt.plot(k_range, knn_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %%
index = knn_cv_mean_scores.index(max(knn_cv_mean_scores))
maxCV = max(knn_cv_mean_scores)
k = k_range[index]
knnAccuracyScore = knn_scores[index]
print('Max of k_score cross validation: ', maxCV)
print("K : " , k)
print("Accuracy score on test data: " ,knnAccuracyScore)
# Out:
# Max of k_score cross validation:  0.6248801987922935
# K :  91
# Accuracy score on test data:  0.6230475493016687

# %% [markdown]
# ## Evaluate K-NN

# %%
X_train = getX(trainData)
y_train = getY(trainData)

# %%
knn = KNeighborsClassifier(n_neighbors=45)
knn = knn.fit(X_train, y_train)

# %%
X = getX(testData)
y = getY(testData)

# %%
y_pred = knn.predict(X)
metrics.accuracy_score(y, y_pred)
# Out:
# 0.6278974447476567

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # conclusion :
#
# ### * The number of backers has a big impact on success and pledged
#
# ### * its importent to choose a good name to the project, we have seen that has a connection with words that repeated in successful projects.
#
# ### * goal is important. consider your goal before you set it , too high goal attract less backers.
#
# ### * Category are important. make sure you got a project that intersting pepole , the category need to be ine that attract your backers.
#
# ### * Prefer using in frequency words, the name need to be simple and clear.
#
# ### * Publish project to noraml duration, not too long and not too short, normal is about a 30 days
#
# ### * Time is imporrtant publish your project
#
#     * Its prefer to publish your project between Feb to Oct.
#
#     * Its prefer to publish your project between Thu to Fri.
#
#     *  Its prefer to publish your project between 15:00 to 20:00
#
# ### * words len and name len are importatnt
#
#     * Choose a name with at least 6-7 words . (but not too much more then that).
#
#     * try to use in a short words. not too long word.
#
# ### * stopwords, exclamation, question, numbers, time, symbol , url and more are good but not too much.

# %% [markdown]
# <br>
# <br>
# <br>
#
#
# # prediction results:
#
# ### * we get our best result with Random Forest Classifier.
# ### * Accuracy score is 69% percent in Random Forest Classifier prediction.
# ### * in this algorithm the most important featurs are:
#     * name_success_value
#     * goal
#     * success_percent_category
#     * name_freq_value
#     * duration
#     * pledged_median_category
#     * day
#     * hour
#     * backers_median_category
#     * weekday
#     * clean_name_word_count
